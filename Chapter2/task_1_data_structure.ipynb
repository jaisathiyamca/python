# %% [markdown]
# # 2. Data structure Excercise

# %% [markdown]
# ### 2.1 List Data structure

# %% [markdown]
# ### To create list of names

# %%
lstNames=list(["sathiya","sabari","inba","ashok","babu","chandra","dravid"])

# %%
type(lstNames)
# Out:
# list

# %%
lstNames
# Out:
# ['sathiya', 'sabari', 'inba', 'ashok', 'babu', 'chandra', 'dravid']

# %% [markdown]
# ### To add new name in the existing list

# %%
lstNames.append('mani')

# %%
lstNames
# Out:
# ['sathiya',
#  'sabari',
#  'inba',
#  'ashok',
#  'babu',
#  'chandra',
#  'dravid',
#  'mani',
#  'mani']

# %% [markdown]
# ### To clear items in the list

# %%
lstNames.clear()
lstNames
# Out:
# []

# %% [markdown]
# ### To create shallow copy of the list

# %%
lstNames=list(["sathiya","sabari","inba","ashok","babu","chandra","dravid"])

# %%
copy_lstName=lstNames.copy()

# %%
print(copy_lstName)
# Out:
# ['sathiya', 'sabari', 'inba', 'ashok', 'babu', 'chandra', 'dravid']

# %%
copy_lstName.append("selva")

# %%
print(copy_lstName)
# Out:
# ['sathiya', 'sabari', 'inba', 'ashok', 'babu', 'chandra', 'dravid', 'selva']

# %%
print(lstNames)
# Out:
# ['sathiya', 'sabari', 'inba', 'ashok', 'babu', 'chandra', 'dravid']

# %% [markdown]
# ### To get count of the item in the list

# %%
lstNames.count('sathiya')
# Out:
# 1

# %%
lstNames.append('sathiya')
lstNames
# Out:
# ['sathiya',
#  'sabari',
#  'inba',
#  'ashok',
#  'babu',
#  'chandra',
#  'dravid',
#  'sathiya',
#  'sathiya']

# %%
lstNames.count('sathiya')
# Out:
# 3

# %% [markdown]
# ### To add list of values in the existing list

# %%
lstNames
# Out:
# ['sathiya',
#  'sabari',
#  'inba',
#  'ashok',
#  'babu',
#  'chandra',
#  'dravid',
#  'sathiya',
#  'sathiya']

# %%
lstNames.extend(['mohana','soundharya','sumathi'])

# %%
lstNames
# Out:
# ['sathiya',
#  'sabari',
#  'inba',
#  'ashok',
#  'babu',
#  'chandra',
#  'dravid',
#  'sathiya',
#  'sathiya',
#  'mohana',
#  'soundharya',
#  'sumathi']

# %% [markdown]
# ### To get index of the given object in the list

# %%
lstNames.index('inba')
# Out:
# 2

# %% [markdown]
# ### To add object in the list to the given index

# %%
lstNames.insert(1,'divya')

# %%
lstNames
# Out:
# ['sathiya',
#  'divya',
#  'sabari',
#  'inba',
#  'ashok',
#  'babu',
#  'chandra',
#  'dravid',
#  'sathiya',
#  'sathiya',
#  'mohana',
#  'soundharya',
#  'sumathi']

# %% [markdown]
# ### To get recently added object in the list and remove from the list

# %%
lstNames.pop()
# Out:
# 'sumathi'

# %%
lstNames
# Out:
# ['sathiya',
#  'divya',
#  'sabari',
#  'inba',
#  'ashok',
#  'babu',
#  'chandra',
#  'dravid',
#  'sathiya',
#  'sathiya',
#  'mohana',
#  'soundharya']

# %% [markdown]
# ### To remove the first occurance of the object in the list

# %%
lstNames.remove('sathiya')

# %%
lstNames
# Out:
# ['divya',
#  'sabari',
#  'inba',
#  'ashok',
#  'babu',
#  'chandra',
#  'dravid',
#  'sathiya',
#  'sathiya',
#  'mohana',
#  'soundharya']

# %% [markdown]
# ### To reverse objects order in the list

# %%
lstNames.reverse()

# %%
lstNames
# Out:
# ['soundharya',
#  'mohana',
#  'sathiya',
#  'sathiya',
#  'dravid',
#  'chandra',
#  'babu',
#  'ashok',
#  'inba',
#  'sabari',
#  'divya']

# %% [markdown]
# ### To sort list of objects

# %%
lstNames.sort()

# %%
lstNames
# Out:
# ['ashok',
#  'babu',
#  'chandra',
#  'divya',
#  'dravid',
#  'inba',
#  'mohana',
#  'sabari',
#  'sathiya',
#  'sathiya',
#  'soundharya']

# %%
lstNames.sort(reverse=True)

# %%
lstNames
# Out:
# ['soundharya',
#  'sathiya',
#  'sathiya',
#  'sabari',
#  'mohana',
#  'inba',
#  'dravid',
#  'divya',
#  'chandra',
#  'babu',
#  'ashok']

# %% [markdown]
# ## 2 Set Data structure

# %%
employees={'sathiya','inba','soundharya','babu'}
employees
# Out:
# {'babu', 'inba', 'sathiya', 'soundharya'}

# %%
type(employees)
# Out:
# set

# %% [markdown]
# ### To add element if object not exist in the set

# %%
employees.add('sathiya')
employees
# Out:
# {'babu', 'inba', 'sathiya', 'soundharya'}

# %%
employees.add('vijaya')

# %%
employees
# Out:
# {'babu', 'inba', 'sathiya', 'soundharya', 'vijaya', 'vijya'}

# %% [markdown]
# ### To clear all objects in the st set

# %%
employees.clear()
employees
# Out:
# set()

# %% [markdown]
# ### To copy elements from one object to another object

# %%
employees={'sathiya','inba','soundharya','babu'}

# %%
copy_employees=employees.copy()

# %%
copy_employees.add('selva')

# %%
print(employees)
# Out:
# {'sathiya', 'employee1', 'inba', 'babu', 'soundharya'}

# %%
print(copy_employees)
# Out:
# {'sathiya', 'inba', 'babu', 'selva', 'soundharya'}

# %% [markdown]
# ### To find the differences between two sets and print unique values in first set

# %%
employees.difference({'sathiya','inba','ashok'})
# Out:
# {'babu', 'employee1', 'soundharya'}

# %% [markdown]
# ### To remove all elements in parent matching with child

# %%
employees
# Out:
# {'babu', 'employee1', 'inba', 'sathiya', 'soundharya'}

# %%
employees.difference_update({'sathiya','inba'})

# %%
employees
# Out:
# {'babu', 'employee1', 'soundharya'}

# %%
employees.difference_update('soundharya1')

# %%
employees
# Out:
# {'babu', 'employee1', 'soundharya'}

# %% [markdown]
# ### To remove an element from set

# %%
employees.discard('employee1')

# %%
employees
# Out:
# {'babu', 'soundharya'}

# %% [markdown]
# ### `To find common elements between two sets

# %%
employees.intersection({'sathiya','babu','soundharya','mani'})
# Out:
# set()

# %% [markdown]
# ### To find common elements between two sets and update original set

# %%
employees={'sathiya','inba','selva','ashok'}

# %%
employees.intersection_update({'inba','selva','selva1'})

# %%
employees
# Out:
# {'inba', 'selva'}

# %% [markdown]
# ### To return true if two sets are different

# %%
employees.isdisjoint({'inba','mani'})
# Out:
# False

# %%
employees
# Out:
# {'inba', 'selva'}

# %% [markdown]
# ### To return true one set is subset of another

# %%
employees={'inba','selva'}

# %%
employees.issubset({'sathiya','inba','selva','ashok'})
# Out:
# True

# %% [markdown]
# ### To check every element in righ side is subset of left hand side

# %%
employees={'inba', 'selva','sathiya'}

# %%
employees.issuperset({'inba','sathiya'})
# Out:
# True

# %% [markdown]
# ### To remove an element from set

# %%
employees
# Out:
# {'inba', 'sathiya', 'selva'}

# %%
employees.pop()
# Out:
# 'sathiya'

# %%
employees
# Out:
# {'inba', 'selva'}

# %%
employees={'inba','sathiya','selva','ashok'}

# %%
employees
# Out:
# {'ashok', 'inba', 'sathiya', 'selva'}

# %%
employees.pop()
# Out:
# 'ashok'

# %% [markdown]
# ### To remove an element from set

# %%
employees
# Out:
# {'inba', 'sathiya', 'selva'}

# %%
employees.remove('inba')

# %%
employees
# Out:
# {'sathiya', 'selva'}

# %%
employees
# Out:
# {'sathiya', 'selva'}

# %%
employees.symmetric_difference({'selva','inba'})
# Out:
# {'inba', 'sathiya'}

# %%
employees
# Out:
# {'sathiya', 'selva'}

# %% [markdown]
# ###  find the difference between two sets and update original set

# %%
employees.symmetric_difference_update({'selva','inba'})

# %%
employees
# Out:
# {'sathiya', 'selva'}

# %% [markdown]
# ### To returns unions of sets

# %%
employees.union('sathiya','inba')
# Out:
# {'a', 'b', 'h', 'i', 'n', 's', 'sathiya', 'selva', 't', 'y'}

# %%
employees
# Out:
# {'sathiya', 'selva'}

# %%
employees.union({'sathiya','inba'})
# Out:
# {'inba', 'sathiya', 'selva'}

# %% [markdown]
# ### To update union of two sets in source set

# %%
employees={'sathiya', 'selva'}

# %%
employees.update({'selva','inba'})

# %%
employees
# Out:
# {'inba', 'sathiya', 'selva'}

# %% [markdown]
# ## Tupple Data structure

# %%
empTupple=(1,'sathiya',2,'selva',3,'inba')

# %%
type(empTupple)
# Out:
# tuple

# %%
empTupple.count('sathiya')
# Out:
# 1

# %%
empTupple.index('selva')
# Out:
# 3

# %%
empTupple[1:]
# Out:
# ('sathiya', 2, 'selva', 3, 'inba')

# %%
empTupple[:-1]
# Out:
# (1, 'sathiya', 2, 'selva', 3)

# %% [markdown]
# ## Dictionary Data structure

# %% [markdown]
# ### To copy dictionary

# %%
empDetails={'name':'sathiya','age':34,'dob':'25-Jan-2008','dept':'ComputerScience'}

# %%
type(empDetails)
# Out:
# dict

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '25-Jan-2008', 'dept': 'ComputerScience'}

# %%
copyEmpDetails=empDetails.copy()

# %%
copyEmpDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '25-Jan-2008', 'dept': 'ComputerScience'}

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '25-Jan-2008', 'dept': 'ComputerScience'}

# %%
copyEmpDetails['name']='selva'

# %%
copyEmpDetails
# Out:
# {'name': 'selva', 'age': 34, 'dob': '25-Jan-2008', 'dept': 'ComputerScience'}

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '25-Jan-2008', 'dept': 'ComputerScience'}

# %% [markdown]
# ### To create dictionary based on the given keys

# %%
type(empDetails.fromkeys(['name','age']))
# Out:
# dict

# %% [markdown]
# ### To get dictionary value to the given key

# %%
empDetails.get('name')
# Out:
# 'sathiya'

# %% [markdown]
# ### To get dictionary items

# %%
empDetails.items()
# Out:
# dict_items([('name', 'sathiya'), ('age', 34), ('dob', '25-Jan-2008'), ('dept', 'ComputerScience')])

# %%
for key,value in empDetails.items():
    print(key,' => ',value)
# Out:
# name  =>  sathiya
# age  =>  34
# dob  =>  25-Jan-2008
# dept  =>  ComputerScience

# %% [markdown]
# ### To get keys in the dictionary

# %%
empDetails.keys()
# Out:
# dict_keys(['name', 'age', 'dob', 'dept'])

# %% [markdown]
# ### To get value from dictionary based on key and remove from dictionary

# %%
empDetails.pop('dob')
# Out:
# '25-Jan-2008'

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dept': 'ComputerScience'}

# %% [markdown]
# ### To print both key and value and remove the same from dictionary

# %%
empDetails.popitem()
# Out:
# ('dept', 'ComputerScience')

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34}

# %% [markdown]
# ### To add new item in the dictionary

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34}

# %%
empDetails.setdefault('dob','25-Jul-2025')
# Out:
# '25-Jul-2025'

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '25-Jul-2025'}

# %% [markdown]
# ### To update existing value in the dictionary to the given key

# %%
empDetails.update({'dob':'30-Jul-2-25'})

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '30-Jul-2-25'}

# %%
empDetails.update({'dob1':'31-Jul-2025'})

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '30-Jul-2-25', 'dob1': '31-Jul-2025'}

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '30-Jul-2-25', 'dob1': '31-Jul-2025'}

# %%
empDetails.values()
# Out:
# dict_values(['sathiya', 34, '30-Jul-2-25', '31-Jul-2025'])

# %%
for emp in empDetails.values():
    print(emp)
# Out:
# sathiya
# 34
# 30-Jul-2-25
# 31-Jul-2025

# %%
empDetails
# Out:
# {'name': 'sathiya', 'age': 34, 'dob': '30-Jul-2-25', 'dob1': '31-Jul-2025'}

# %%
empDetails.clear()

# %%
empDetails
# Out:
# {}
