# %% [markdown]
# ## To create dataframe using dictionaries

# %% [markdown]
# ### Example 1

# %%
empDetails={'name':['sathiya','selva','inba','ashok'],
           'age':[30,35,30,45]}

# %%
empDetails
# Out:
# {'name': ['sathiya', 'selva', 'inba', 'ashok'], 'age': [30, 35, 30, 45]}

# %%
empDetails.get('name')
# Out:
# ['sathiya', 'selva', 'inba', 'ashok']

# %% [markdown]
# ### Example 2

# %%
studentDetails={'name':['sathiya','selva','inba','ashok'],
               'marks':[90,50,60,66],
               'class':[10,11,10,11]}

# %%
studentDetails
# Out:
# {'name': ['sathiya', 'selva', 'inba', 'ashok'],
#  'marks': [90, 50, 60, 66],
#  'class': [10, 11, 10, 11]}

# %% [markdown]
# ### Example 3

# %%
courseDetails={'courseName':['AI','GenAI','Data Science','ML'],
              'courseFee':['22000.00','25000.25','32000.00','43000.00']}

# %%
courseDetails
# Out:
# {'courseName': ['AI', 'GenAI', 'Data Science', 'ML'],
#  'courseFee': ['22000.00', '25000.25', '32000.00', '43000.00']}
