# %% [markdown]
# ### To implement rock,paper and scissor game

# %%
import random

# %%
randomChoice=random.choice(["rock","papper","scissor"])

# %%
randomChoice
# Out:
# 'papper'

# %%
userInput=input('Enter your choice')
print(f'your choice {userInput}')
# Out:
# Enter your choicerock
# your choice rock

# %%
random.randrange(1,4)
# Out:
# 2

# %%
computerChoice={1:'rock',2:'paper',3:'scissor'}

# %%
computerChoice.get(1)
# Out:
# 'rock'

# %% [markdown]
# ### To create game with 5 fixes time user input

# %%
def getUserChoice():
    userInput=int(input("Enter your choice (1- rock, 2-papper, 3-scissor):"))
    return userInput
print(getUserChoice())
# Out:
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# 1

# %%
import random

computerChoice={1:'rock',2:'paper',3:'scissor'}


def getUserChoice():
    while True:
        try:
            userInput=int(input("Enter your choice (1- rock, 2-papper, 3-scissor):"))
            if 1<=userInput and 3>=userInput:
                return userInput
            else:
                print('please enter value between 1 to 3')
        except ValueError:
            print('Invalid entry. Please enter value between 1 to 3')

def game():
    for i in range(0,5):
        computerChoice=random.randrange(1,4)
        userChoice=getUserChoice()
        #if both computer choice and user choice same then tie
        if(computerChoice==userChoice):
            print('Tie')
        # if computer choose rock and user choose paper
        elif (computerChoice==1 and userChoice==2):
            print('You Win')
        # if computer choose rock and user choose scissor
        elif(computerChoice==1 and userChoice==3):
            print('Computer Win')
        # if computer choose papper and user choose rock
        elif(computerChoice==2 and userChoice==1):
            print('Computer Win')
        # if computer choose papper and user choose scissor
        elif(computerChoice==2 and userChoice==3):
            print('You win')
        # if computer choose Scissor and user choose rock
        elif(computerChoice==3 and userChoice==1):
            print('You win')
        # if computer choose Scissor and user choose papper
        elif(computerChoice==3 and userChoice==2):
            print('You win')
game()
# Out:
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# Computer Win
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# You win
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# Tie
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# Tie
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# Computer Win

# %% [markdown]
# #### To create game until user wins

# %%
import random

choices={1:'rock',2:'paper',3:'scissor'}

isUserWin=False
isComputerWin=False

def updateWinStatus(userWin=False,computerWin=False):
    global isUserWin,isComputerWin
    isUserWin=userWin
    isComputerWin=computerWin
    #print('f(computer choice {}, user choice {})',isUserWin,isComputerWin)
    
def getUserChoice():
    while True:
        try:
            userInput=int(input("Enter your choice (1- rock, 2-papper, 3-scissor):"))
            if 1<=userInput and 3>=userInput:
                return userInput
            else:
                print('please enter value between 1 to 3')
        except ValueError:
            print('Invalid entry. Please enter value between 1 to 3')

def game():
    while True:
        computerChoice=random.randrange(1,4)
        userChoice=getUserChoice()
        #print('user choice: {} computer choice: {}'.format({choices.get(computerChoice)},{choices.get(userChoice)}))
        #if both computer choice and user choice same then tie
        if(computerChoice==userChoice):
            #print('Tie')
            updateWinStatus()
        # if computer choose rock and user choose paper
        elif (computerChoice==1 and userChoice==2):
            updateWinStatus(userWin=True)
        # if computer choose rock and user choose scissor
        elif(computerChoice==1 and userChoice==3):
            updateWinStatus(computerWin=True)
        # if computer choose papper and user choose rock
        elif(computerChoice==2 and userChoice==1):
            updateWinStatus(computerWin=True)
        # if computer choose papper and user choose scissor
        elif(computerChoice==2 and userChoice==3):
            updateWinStatus(userWin=True)
        # if computer choose Scissor and user choose rock
        elif(computerChoice==3 and userChoice==1):
            updateWinStatus(userWin=True)
        # if computer choose Scissor and user choose papper
        elif(computerChoice==3 and userChoice==2):
            updateWinStatus(computerWin=True)
            
       # print(('user win {isUserWin} computer win {isComputerWin}'))
        
        if (False==isUserWin and False==isComputerWin) or (True==isUserWin and True==isComputerWin):
            print('Tie. No one wins')
        elif True==isUserWin:
            print('User wins')
            break;
        elif True==isComputerWin:
            print('Computer wins')
    
        
game()
# Out:
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# Computer wins
# Enter your choice (1- rock, 2-papper, 3-scissor):2
# Computer wins
# Enter your choice (1- rock, 2-papper, 3-scissor):2
# Tie. No one wins
# Enter your choice (1- rock, 2-papper, 3-scissor):2
# Tie. No one wins
# Enter your choice (1- rock, 2-papper, 3-scissor):2
# Computer wins
# Enter your choice (1- rock, 2-papper, 3-scissor):3
# User wins

# %% [markdown]
# ### Rock,papper and scissor game . Get user input until to exit the flow

# %%
import random

choices={1:'rock',2:'paper',3:'scissor'}

isUserWin=False
isComputerWin=False

def updateWinStatus(userWin=False,computerWin=False):
    global isUserWin,isComputerWin
    isUserWin=userWin
    isComputerWin=computerWin
    #print('f(computer choice {}, user choice {})',isUserWin,isComputerWin)
    
def getUserChoice():
    while True:
        try:
            userInput=int(input("Enter your choice (1- rock, 2-papper, 3-scissor):"))
            if 1<=userInput and 3>=userInput:
                return userInput
            else:
                print('please enter value between 1 to 3')
        except ValueError:
            print('Invalid entry. Please enter value between 1 to 3')

def game():
    while True:
        computerChoice=random.randrange(1,4)
        userChoice=getUserChoice()
        #print('user choice: {} computer choice: {}'.format({choices.get(computerChoice)},{choices.get(userChoice)}))
        #if both computer choice and user choice same then tie
        if(computerChoice==userChoice):
            #print('Tie')
            updateWinStatus()
        # if computer choose rock and user choose paper
        elif (computerChoice==1 and userChoice==2):
            updateWinStatus(userWin=True)
        # if computer choose rock and user choose scissor
        elif(computerChoice==1 and userChoice==3):
            updateWinStatus(computerWin=True)
        # if computer choose papper and user choose rock
        elif(computerChoice==2 and userChoice==1):
            updateWinStatus(computerWin=True)
        # if computer choose papper and user choose scissor
        elif(computerChoice==2 and userChoice==3):
            updateWinStatus(userWin=True)
        # if computer choose Scissor and user choose rock
        elif(computerChoice==3 and userChoice==1):
            updateWinStatus(userWin=True)
        # if computer choose Scissor and user choose papper
        elif(computerChoice==3 and userChoice==2):
            updateWinStatus(computerWin=True)
            
       # print(('user win {isUserWin} computer win {isComputerWin}'))
        
        if (False==isUserWin and False==isComputerWin) or (True==isUserWin and True==isComputerWin):
            print('Tie. No one wins')
        elif True==isUserWin:
            print('User wins')
        elif True==isComputerWin:
            print('Computer wins')
            
        iscontinue=int(input('''Do you want to continue?
        1-continue
        2-exit : '''))
        if(iscontinue==2):
            break
        
game()
# Out:
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# User wins
# Do you want to continue?
#         1-continue
#         2-exit1
# Enter your choice (1- rock, 2-papper, 3-scissor):1
# Computer wins
# Do you want to continue?
#         1-continue
#         2-exit2
