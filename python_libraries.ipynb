# %% [markdown]
# ## Python libraries

# %% [markdown]
# To practice to python libraries

# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 1.9 MB/s eta 0:00:00 eta 0:00:010:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
cars_data=pd.read_csv(filepath_or_buffer="data.csv")
print(cars_data)
type(cars_data)
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
type(cars_data)
# Out:
# pandas.core.frame.DataFrame

# %%
cars_data_array=cars_data.values
#np.repeat(a=cars_data_array,repeats=3,axis=0)
print(cars_data_array)
# Out:
# [['Toyoty' 'Aygo' 1000 790 99]
#  ['Mitsubishi' 'Space Star' 1200 1160 95]
#  ['Skoda' 'Citigo' 1000 929 95]
#  ['Fiat' '500' 900 865 90]
#  ['Mini' 'Cooper' 1500 1140 105]
#  ['VW' 'Up!' 1000 929 105]
#  ['Skoda' 'Fabia' 1400 1109 90]
#  ['Mercedes' 'A-Class' 1500 1365 92]
#  ['Ford' 'Fiesta' 1500 1112 98]
#  ['Audi' 'A1' 1600 1150 99]
#  ['Hyundai' 'I20' 1100 980 99]
#  ['Suzuki' 'Swift' 1300 990 101]
#  ['Ford' 'Fiesta' 1000 1112 99]
#  ['Honda' 'Civic' 1600 1252 94]
#  ['Hundai' 'I30' 1600 1326 97]
#  ['Opel' 'Astra' 1600 1330 97]
#  ['BMW' '1' 1600 1365 99]
#  ['Mazda' '3' 2200 1280 104]
#  ['Skoda' 'Rapid' 1600 1119 104]
#  ['Ford' 'Focus' 2000 1328 105]
#  ['Ford' 'Mondeo' 1600 1584 94]
#  ['Opel' 'Insignia' 2000 1428 99]
#  ['Mercedes' 'C-Class' 2100 1365 99]
#  ['Skoda' 'Octavia' 1600 1415 99]
#  ['Volvo' 'S60' 2000 1415 99]
#  ['Mercedes' 'CLA' 1500 1465 102]
#  ['Audi' 'A4' 2000 1490 104]
#  ['Audi' 'A6' 2000 1725 114]
#  ['Volvo' 'V70' 1600 1523 109]
# ...

# %%
np.repeat(a=cars_data_array,repeats=3,axis=1)
# Out:
# array([['Toyoty', 'Toyoty', 'Toyoty', 'Aygo', 'Aygo', 'Aygo', 1000, 1000,
#         1000, 790, 790, 790, 99, 99, 99],
#        ['Mitsubishi', 'Mitsubishi', 'Mitsubishi', 'Space Star',
#         'Space Star', 'Space Star', 1200, 1200, 1200, 1160, 1160, 1160,
#         95, 95, 95],
#        ['Skoda', 'Skoda', 'Skoda', 'Citigo', 'Citigo', 'Citigo', 1000,
#         1000, 1000, 929, 929, 929, 95, 95, 95],
#        ['Fiat', 'Fiat', 'Fiat', '500', '500', '500', 900, 900, 900, 865,
#         865, 865, 90, 90, 90],
#        ['Mini', 'Mini', 'Mini', 'Cooper', 'Cooper', 'Cooper', 1500, 1500,
#         1500, 1140, 1140, 1140, 105, 105, 105],
#        ['VW', 'VW', 'VW', 'Up!', 'Up!', 'Up!', 1000, 1000, 1000, 929,
#         929, 929, 105, 105, 105],
#        ['Skoda', 'Skoda', 'Skoda', 'Fabia', 'Fabia', 'Fabia', 1400, 1400,
#         1400, 1109, 1109, 1109, 90, 90, 90],
#        ['Mercedes', 'Mercedes', 'Mercedes', 'A-Class', 'A-Class',
# ...

# %% [markdown]
# ## Matplotlib

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 1.7 MB/s eta 0:00:001.0 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 9.5 MB/s eta 0:00:003 MB/s eta 0:00:0101
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as py

# %%
print(cars_data)
py.bar(x=cars_data.CO2,height=100)
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...
