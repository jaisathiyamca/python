# %% [markdown]
# ## To excercise python

# %%
class Employee:
    def __init__(self,name,dob):
        self.name=name
        self.__dob=dob
    
    def getDetails(self):
        return f"{self.name} {self.dob}welcome to employee"

# %%
sathiya=Employee("sathiya","25/07/1990")
sathiya.name='sathiya'
sathiya.dob='31/08/1990'

# %%
sathiya.getDetails()
# Out:
# 'sathiya 31/08/1990welcome to employee'
